# %% [markdown]
# # EXPLORATORY DATA ANALYSIS - NUMERICAL AND GRAPHICAL METHODS FOR DATA EXPLORATION

# %% [markdown]
# ## 1. How to estimate the measures of central tendency and dispersion.

# %% [markdown]
# ## 2.Different ways of visualizing one variable.

# %% [markdown]
# ## 3. Different ways of visualizing multiple variables.

# %%
import pandas as pd

# %%
heart_df = pd.read_csv("heart.csv",skiprows=[0],names= ["Age","Sex","Chest Pain","Blood Pressure","Cholesterol","Diabetes","ECG Result","Max Heart Rate","Angina","ST Depression","ST Slope","# Major Vessels Coloured","Thal","Diagnosis"])

# %%
heart_df
# Out:
#      Age  Sex  Chest Pain  Blood Pressure  Cholesterol  Diabetes  ECG Result  \
# 0     63    1           3             145          233         1           0
# 1     37    1           2             130          250         0           1
# 2     41    0           1             130          204         0           0
# 3     56    1           1             120          236         0           1
# 4     57    0           0             120          354         0           1
# ..   ...  ...         ...             ...          ...       ...         ...
# 298   57    0           0             140          241         0           1
# 299   45    1           3             110          264         0           1
# 300   68    1           0             144          193         1           1
# 301   57    1           0             130          131         0           1
# 302   57    0           1             130          236         0           0
#
# ...

# %%
heart_df.shape
# Out:
# (303, 14)

# %%
heart_df.columns
# Out:
# Index(['Age', 'Sex', 'Chest Pain', 'Blood Pressure', 'Cholesterol', 'Diabetes',
#        'ECG Result', 'Max Heart Rate', 'Angina', 'ST Depression', 'ST Slope',
#        '# Major Vessels Coloured', 'Thal', 'Diagnosis'],
#       dtype='object')

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       303 non-null    int64
#  1   Sex                       303 non-null    int64
#  2   Chest Pain                303 non-null    int64
#  3   Blood Pressure            303 non-null    int64
#  4   Cholesterol               303 non-null    int64
#  5   Diabetes                  303 non-null    int64
#  6   ECG Result                303 non-null    int64
#  7   Max Heart Rate            303 non-null    int64
#  8   Angina                    303 non-null    int64
#  9   ST Depression             303 non-null    float64
#  10  ST Slope                  303 non-null    int64
#  11  # Major Vessels Coloured  303 non-null    int64
#  12  Thal                      303 non-null    int64
#  13  Diagnosis                 303 non-null    int64
# ...

# %%
# Except ST Depression, the rest of the variables in our dataset have the type int64. But we know that Age, Blood Pressure and Cholesterol are continous variables.
# Let us chnge the Dtype for these three variables.

# %%
heart_df[["Age","Cholesterol","Blood Pressure"]] = heart_df[["Age","Cholesterol","Blood Pressure"]].astype("double")

# %%
#Now we can verify if our Dtype converson has been successful

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       303 non-null    float64
#  1   Sex                       303 non-null    int64
#  2   Chest Pain                303 non-null    int64
#  3   Blood Pressure            303 non-null    float64
#  4   Cholesterol               303 non-null    float64
#  5   Diabetes                  303 non-null    int64
#  6   ECG Result                303 non-null    int64
#  7   Max Heart Rate            303 non-null    int64
#  8   Angina                    303 non-null    int64
#  9   ST Depression             303 non-null    float64
#  10  ST Slope                  303 non-null    int64
#  11  # Major Vessels Coloured  303 non-null    int64
#  12  Thal                      303 non-null    int64
#  13  Diagnosis                 303 non-null    int64
# ...

# %% [markdown]
# #### Working with single variable

# %%
heart_df["Age"].mean(axis =0)
# Out:
# 54.366336633663366

# %% [markdown]
# Similarly we can also find the variance and standard deviation for age

# %%
var_age = heart_df["Age"].var(axis =0)
sd_age = heart_df["Age"].std(axis=0)
print("Variance",var_age)
print("Standard Deviation",sd_age)
# Out:
# Variance 82.48455838961381
# Standard Deviation 9.082100989837858

# %%
heart_df["Age"].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: Age, dtype: float64

# %% [markdown]
# min and max age is 29 and 77,-->  range
# The 2nd quartile is also the median age
# Likewise, we can find out interquartile range for age.

# %%
age_itr = 61 - 47
print("The interquartile range for age is",age_itr)
# Out:
# The interquartile range for age is 14

# %% [markdown]
# Now, let us visualize the distribution of age in our dataset.

# %%
import matplotlib.pyplot as plt

# %%
from pylab import hist, show,xticks,yticks
ax = plt.subplots(figsize = (10,7))
plt.hist(heart_df["Age"],bins=[20,30,40,50,60,70,80],color="plum",edgecolor="black")
xticks(range(20,90,10))
yticks(range(0,150,25))
plt.xlabel("Age",fontsize = 20)
plt.ylabel("No. of Occurence",fontsize = 20)
plt.tick_params(axis = "both",which="major",labelsize = 18)
plt.show()

# %% [markdown]
# Now let us generate a Box Plot

# %%
from pylab import *
fig = figure(figsize = (10,10))
plt.boxplot(heart_df["Age"])
plt.ylabel("Age",fontsize = 20)
plt.tick_params(axis = "both",which="major",labelsize = 18)
plt.show()

# %%
Working with multiple variables

# %%
heart_df[["Age","Blood Pressure","Cholesterol","Max Heart Rate"]].describe()
# Out:
#               Age  Blood Pressure  Cholesterol  Max Heart Rate
# count  303.000000      303.000000   303.000000      303.000000
# mean    54.366337      131.623762   246.264026      149.646865
# std      9.082101       17.538143    51.830751       22.905161
# min     29.000000       94.000000   126.000000       71.000000
# 25%     47.500000      120.000000   211.000000      133.500000
# 50%     55.000000      130.000000   240.000000      153.000000
# 75%     61.000000      140.000000   274.500000      166.000000
# max     77.000000      200.000000   564.000000      202.000000

# %% [markdown]
# We will use Python Seaborn Package to visualize these variables

# %%
import seaborn as sns

# %%
sns.histplot(data = heart_df, x ="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data = heart_df, x ="Blood Pressure")
# Out:
# <Axes: xlabel='Blood Pressure', ylabel='Count'>

# %% [markdown]
# There are a few people with very high blood pressure. This si positively skewed/ right skewed distribution

# %%
sns.histplot(data = heart_df, x ="Cholesterol")
# Out:
# <Axes: xlabel='Cholesterol', ylabel='Count'>

# %% [markdown]
# Cholesterol has outlier with a value >500 mg/dl. This, again is a positively skewed distribution.

# %%
sns.histplot(data = heart_df, x ="Max Heart Rate")
# Out:
# <Axes: xlabel='Max Heart Rate', ylabel='Count'>

# %% [markdown]
# Maximum heart rate has a tail towards the left i.e. this is left skewed/ negatively skewed distribution.

# %% [markdown]
# We may like to know how many normal and diseased poeple are in our dataset. We will use Seaborn countplot

# %%
sns.countplot(data=heart_df,x="Diagnosis").set_xticklabels(["Normal","Diseased"])
# Out:
# [Text(0, 0, 'Normal'), Text(1, 0, 'Diseased')]

# %% [markdown]
# Similarly, we may be interested in gender distribution in our dataset.

# %%
sns.countplot(data = heart_df, x = "Sex").set_xticklabels(["Female","Male"])
# Out:
# [Text(0, 0, 'Female'), Text(1, 0, 'Male')]

# %% [markdown]
# Let us compare the blood pressure values for people with and without heart disease

# %%
sns.boxplot(data = heart_df,y= "Blood Pressure", x = "Diagnosis").set_xticklabels(["Normal","Diseased"])
# Out:
# [Text(0, 0, 'Normal'), Text(1, 0, 'Diseased')]

# %% [markdown]
# Surprisingly, the median blood pressure in the Normal group is higher than in Diseased group.
# We can also visualize and compare the means instead of median

# %%
sns.boxplot(data = heart_df,y= "Blood Pressure", x = "Diagnosis", showmeans = "True").set_xticklabels(["Normal","Diseased"])
# Out:
# [Text(0, 0, 'Normal'), Text(1, 0, 'Diseased')]

# %% [markdown]
# Similarly, we can compare Age,Cholesterol, Max heart rate with diagnosis

# %% [markdown]
# Now, let us investigate ECG

# %%
sns.barplot(data = heart_df,y= "Blood Pressure", x = "ECG Result",errorbar = "sd", capsize = 0.1).set_xticklabels(["Normal","Intermediate","Severe"])
# Out:
# [Text(0, 0, 'Normal'), Text(1, 0, 'Intermediate'), Text(2, 0, 'Severe')]

# %% [markdown]
# Blood pressure among people with "Severe" ECG result is relatively higher.

# %% [markdown]
# Scatterplots

# %% [markdown]
# The relation between different pairs of continous variables in our dataset.

# %%
plt.scatter(heart_df["Age"],heart_df["Blood Pressure"])

# %%
plt.scatter(heart_df["Cholesterol"],heart_df["Blood Pressure"])
plt.xlabel("Cholesterol (in mg/dL)",fontsize = 12)
plt.ylabel("Blood Pressure (in mmHg)", fontsize = 12)
# Out:
# Text(0, 0.5, 'Blood Pressure (in mmHg)')

# %%
plt.scatter(heart_df["Max Heart Rate"],heart_df["Blood Pressure"])
plt.xlabel("Max Heart Rate",fontsize = 12)
plt.ylabel("Blood Pressure (in mmHg)", fontsize = 12)
# Out:
# Text(0, 0.5, 'Blood Pressure (in mmHg)')

# %%
plt.scatter(heart_df["Age"],heart_df["Max Heart Rate"])
plt.xlabel("Age",fontsize = 12)
plt.ylabel("Max Heart Rate", fontsize = 12)
# Out:
# Text(0, 0.5, 'Max Heart Rate')

# %% [markdown]
# We can find the correlation coefficient among these four variables.

# %%
heart_df[["Age","Blood Pressure","Cholesterol","Max Heart Rate"]].corr()
# Out:
#                      Age  Blood Pressure  Cholesterol  Max Heart Rate
# Age             1.000000        0.279351     0.213678       -0.398522
# Blood Pressure  0.279351        1.000000     0.123174       -0.046698
# Cholesterol     0.213678        0.123174     1.000000       -0.009940
# Max Heart Rate -0.398522       -0.046698    -0.009940        1.000000

# %% [markdown]
# Max heart Rate has considerable negative correaltion with Age i.e. older people have lower max heart rate. Blood pressure also seem to increase with age as we can see that the corelation between these two variables is 0.28.
#
# Now, we are interested in how age affects blood pressure i.e. we may try to understad blood pressure as a function of age. This can modelled as linear relationship between blood pressure and age as follow:
# blood_pressure = slope * age + intercept
# We can estimate the unknowns Slope and Intercept and plot:

# %%
import numpy as np

# %%
Slope, Intercept = np.polyfit(heart_df["Age"], heart_df["Blood Pressure"],1)
print("Slope",Slope)
print("Intercept",Intercept)
# Out:
# Slope 0.5394452340751631
# Intercept 102.29610118508198

# %% [markdown]
# Now we have estimated Slope and intercept, now we plot regression straight line.

# %%
plt.plot(heart_df["Age"],heart_df["Blood Pressure"],"o")
plt.plot(heart_df["Age"],Slope + heart_df["Age"] + Intercept)
plt.xlabel("Age",fontsize = 15)
plt.ylabel("Blood Pressure",fontsize = 15)
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %% [markdown]
# we can plot all of them together in a single figure using seaborn pairplot command.

# %%
sns.pairplot(heart_df[["Age","Blood Pressure","Cholesterol","Max Heart Rate"]])
# Out:
# C:\Users\Rehan Ansari\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# This kind of plot is known as scatterplot matrix.
